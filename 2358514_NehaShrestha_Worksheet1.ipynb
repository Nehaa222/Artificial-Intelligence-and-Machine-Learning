# %% [markdown]
# Name: Neha Shrestha
#
# Section: L6CG19
#
# WORKSHEET1

# %% [markdown]
# #Getting Started with Image Processing with Python.

# %% [markdown]
# #Exercise - 1

# %% [markdown]
# 1. Read and display the image.
#
#   • Read the image using the Pillow library and display it.
#
#   • You can also use matplotlib to display the image.

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
image = Image.open("/content/drive/MyDrive/Artificial Intelligence and Machine Learning/lenna_image.png")

# %%
plt.imshow(image)
plt.axis('off')
plt.title("Original Image")
plt.show()

# %%
print("Format:", image.format)#image format kun ma cha bhaney dincha
print("Mode:", image.mode)#RGBA where A is transparency(alpha value) visibility ma changes aaucha "a" bata
print("Size:", image.size)#width, height
# Out:
# Format: PNG
# Mode: RGBA
# Size: (366, 357)

# %%
image = image.convert("RGB")
print(image.mode)
# Out:
# RGB

# %% [markdown]
# 2. Display only the top left corner of 100x100 pixels.
#
#   • Extract the top-left corner of the image (100x100 pixels) and display it using NumPy and
#   Array Indexing.

# %%
import numpy as np
image_array = np.array(image)
print(image_array.shape)
# Out:
# (357, 366, 3)

# %%
top_left_corner = image_array[:100, :100]
plt.imshow(top_left_corner)
plt.axis('off')
plt.title("Top left corner of 100 x 100 pixels")
plt.show()

# %% [markdown]
# 3. Show the three color channels (R, G, B).
#
#   • Separate the image into its three color channels (Red, Green, and Blue) and display them
#   individually, labeling each channel as R, G, and B.{Using NumPy.}

# %%
plt.figure(figsize=(10,4))
# red chanel
red_channel = image_array.copy()
red_channel[:,:, 1] = 0 # green = 0
red_channel[:,:, 2] = 0 # blue = 0

plt.subplot(1, 3, 1)
plt.imshow(red_channel)
plt.title('Red Channel')
plt.axis('off')

# green chanel
green_channel = image_array.copy()
green_channel[:,:, 0] = 0 # red = 0
green_channel[:,:, 2] = 0 # blue = 0

plt.subplot(1, 3, 2)
plt.imshow(green_channel)
plt.title('Green Channel')
plt.axis('off')

blue_channel = image_array.copy()
blue_channel[:,:, 0] = 0 # red = 0
blue_channel[:,:, 1] = 0 # green = 0

plt.subplot(1, 3, 3)
plt.imshow(blue_channel)
plt.title('Blue Channel')
plt.axis('off')

plt.show()

# %% [markdown]
# 4. Modify the top 100 × 100 pixels to a value of 210 and display the resulting image:
#
#   • Modify the pixel values of the top-left 100 × 100 region to have a value of 210 (which is a
#   light gray color), and then display the modified image.

# %%
modified_image = image_array.copy()
modified_image[:100, :100] = 210

plt.imshow(modified_image)
plt.title('Modified Image (Top 100x100 to 210)')
plt.axis('off')
plt.show()

# %% [markdown]
# #Exercise 2

# %% [markdown]
# 1. Load and display a grayscale image.
#
#   • Load a grayscale image using the Pillow library.
#
#   • Display the grayscale image using matplotlib.

# %%
# importing the image as gray
imported_image = Image.open("/content/drive/MyDrive/Artificial Intelligence and Machine Learning/camera_man.jpg").convert('L')

# %%
plt.imshow(imported_image, cmap='gray')
plt.axis('off')
plt.title("Grayscale Image")
plt.show()

# %% [markdown]
# 2. Extract and display the middle section of the image (150 pixels).
#
#   • Extract a 150 pixel section from the center of the image using NumPy array slicing.
#
#   • Display this cropped image using matplotlib.

# %%
gray_image_array = np.array(imported_image)
print(gray_image_array.shape)
# Out:
# (325, 220)

# %%
# Extracting the center of the image
height, width = gray_image_array.shape
center_point_x = width//2
left = max(0, center_point_x - 75)
right = min(width, center_point_x + 75)

center_point_y = height//2
upper = max(0, center_point_y - 75)
lower = min(height, center_point_y + 75)

# Extract the middle section using numpy slicing
cropped_image_array = gray_image_array[upper:lower, left:right]

# Create a cropped image from the extracted array
cropped_image = Image.fromarray(cropped_image_array)

plt.imshow(cropped_image, cmap='gray')
plt.axis('off')
plt.title("Cropped Image")
plt.show()

# %% [markdown]
# 3. Apply a simple threshold to the image (e.g., set all pixel values below 100 to 0).
#
#   • Apply a threshold to the grayscale image: set all pixel values below 100 to 0, and all values
#   above 100 to 255 (creating a binary image).
#
#   • Display the resulting binary image.

# %%
gray_array = np.array(gray_image_array)
binary_image = np.where(gray_array < 100, 0, 255)
plt.imshow(binary_image, cmap="gray")
plt.title("Binary Image")
plt.axis("off")
plt.show()

# %% [markdown]
# 4. Rotate the image 90 degrees clockwise and display the result.
#
#   • Rotate the image by 90 degrees clockwise using the Pillow rotate method or by manipulating
#   the image array.
#
#   • Display the rotated image using matplotlib.

# %%
rotated_image = imported_image.rotate(-90, expand = True)

plt.imshow(rotated_image, cmap = 'gray')
plt.title("Rotated Image (90° Clockwise)")
plt.axis("off")
plt.show()

# %% [markdown]
# 5. Convert the grayscale image to an RGB image.
#
#   • Convert the grayscale image into an RGB image where the grayscale values are replicated
#   across all three channels (R, G, and B).
#
#   • Display the converted RGB image using matplotlib.

# %%
gray_image_array = np.array(imported_image)

# replicate/stack grayscale values across R,G and B
rgb_image_array = np.stack([gray_image_array]*3, axis = -1)
rgb_image = Image.fromarray(rgb_image_array)

plt.imshow(rgb_image)
plt.axis('off')
plt.title("RGB Image")
plt.show()

# %%
print(gray_image_array)
print(rgb_image_array)
# Out:
# [[236 236 237 ... 238 238 237]
#  [237 237 238 ... 238 239 239]
#  [237 238 239 ... 238 239 239]
#  ...
#  [196 200 204 ... 167 166 165]
#  [196 199 203 ... 166 166 164]
#  [197 201 205 ... 164 166 165]]
# [[[236 236 236]
#   [236 236 236]
#   [237 237 237]
#   ...
#   [238 238 238]
#   [238 238 238]
#   [237 237 237]]
#
#  [[237 237 237]
#   [237 237 237]
#   [238 238 238]
#   ...
#   [238 238 238]
#   [239 239 239]
#   [239 239 239]]
#
#  [[237 237 237]
#   [238 238 238]
#   [239 239 239]
#   ...
#   [238 238 238]
#   [239 239 239]
#   [239 239 239]]
#
#  ...
#
#  [[196 196 196]
#   [200 200 200]
#   [204 204 204]
#   ...
#   [167 167 167]
#   [166 166 166]
#   [165 165 165]]
#
#  [[196 196 196]
#   [199 199 199]
#   [203 203 203]
#   ...
#   [166 166 166]
#   [166 166 166]
#   [164 164 164]]
#
#  [[197 197 197]
#   [201 201 201]
#   [205 205 205]
#   ...
#   [164 164 164]
#   [166 166 166]
#   [165 165 165]]]

# %% [markdown]
# #3 Image Compression and Decompression using PCA.

# %% [markdown]
# 1. Load and Prepare Data:
#
#   • Fetch an image of you choice.{If colour convert to grayscale}
#
#   • Center the dataset - Standaridze the Data.
#
#   • Calculate the covaraince matrix of the Standaridze data.
#
#
# 2. Eigen Decomposition and Identifying Principal Components:
#
#   • Compute Eigen Values and Eigen Vectors.
#
#   • Sort the eigenvalues in descending order and choose the top k eigenvectors corresponding to
#   the highest eigenvalues.
#
#   • Identify the Principal Components with the help of cumulative Sum plot.
#
# 3. Reconstruction and Experiment:
#
#   • Reconstruction: Transform the original data by multiplying it with the selected eigenvec-
#   tors(PCs) to obtain a lower-dimensional representation.
#
#   • Experiments: Pick Four different combination of principal components with various ex-
#   plained variance value and compare the result.
#
#   • Display the Results and Evaluate.

# %%
# 1. Load and standardize grayscale image
data = np.array(imported_image)
mean = np.mean(data, axis=0)
centered_data = data - mean

# 2. Compute covariance matrix and eigenvalues
cov_matrix = np.cov(centered_data, rowvar=False)
eigenvalues, eigenvectors = np.linalg.eigh(cov_matrix)

# 3. Sort eigenvalues in descending order
sorted_indices = np.argsort(eigenvalues)[::-1]
eigenvalues = eigenvalues[sorted_indices]
eigenvectors = eigenvectors[:, sorted_indices]

# Plot explained variance
explained_variance_ratio = eigenvalues / np.sum(eigenvalues)
plt.plot(np.cumsum(explained_variance_ratio))
plt.title("Cumulative Explained Variance")
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Variance")
plt.grid(True)
plt.show()

# 4. Choose k principal components
k_values = [10, 20, 50, 100, 150]
fig, axes = plt.subplots(2, 3, figsize=(15, 10))

axes = axes.flatten()
axes[0].imshow(data, cmap='gray')
axes[0].set_title("Original")
axes[0].axis("off")

for i, k in enumerate(k_values):
    components = eigenvectors[:, :k]
    compressed_data = np.dot(centered_data, components)
    decompressed_data = np.dot(compressed_data, components.T) + mean
    axes[i+1].imshow(decompressed_data, cmap='gray')
    axes[i+1].set_title(f"{k} Components")
    axes[i+1].axis("off")

plt.show()

# %% [markdown]
# Firstly, started by loading a grayscale image and standardizing it by subtracting the mean. Then, calculated the covariance matrix and found the eigenvalues and eigenvectors. By sorting the eigenvectors in descending order, picked the most important ones, called principal components.
#
# To decide how many components to use, checked the cumulative explained variance plot. Then, tested different numbers of components to see how well they could reconstruct the image.
#
# * 10 components: The image is barely visible, showing only the basic shape.
#
# * 20 components: The image is still blurry but more recognizable.
#
# * 50 components: The image looks much clearer and similar to the original.
#
# * 100 components: The reconstructed image is almost identical to the original.
#
# * 150 components: No major improvement; the image quality stays the same.
#
# This shows that we can use PCA as it helps reduce image size while keeping important details. Using 50 to 100 components is enough to recreate the image without noticeable loss.
